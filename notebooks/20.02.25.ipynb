# %%
import time

import pandas as pd
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
)

import nltk
from nltk.corpus import wordnet 
import string
import re
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense,
    Dropout,
    Embedding,
    Input,
    Flatten,
    Conv1D,
    MaxPooling1D,
    concatenate,
    Conv2D,
    MaxPooling2D
)


from tensorflow.keras.utils import plot_model
from tensorflow.keras import utils

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence


from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

# %%
train = pd.read_csv('/Users/dianaterraza/Desktop/NLP/Data/train_processed.csv', on_bad_lines='skip')
test = pd.read_csv('/Users/dianaterraza/Desktop/NLP/Data/test_processed.csv', on_bad_lines= 'skip')

# %%
train.head(3)
# Out:
#                                               review sentiment  word_counts  \
# 0  If you are looking for a movie that doesn't ta...  positive          271
# 1  THE BEAVER TRILOGY is, without a doubt, one of...  positive          217
# 2  If Andrei Tarkovsky had been a hack, he would ...  negative          118
#
#                                     review_processed  sentiment_encoded
# 0  look movie doesnt take seriously haggard must ...                  1
# 1  beaver trilogy without doubt one brilliant fil...                  1
# 2  andrei tarkovsky hack would direct mother son ...                  0

# %%
def create_tokenizer(corpus, max_len):
    tokenizer = Tokenizer(char_level=False, # if i put true the tokens are characters and we want words
                          oov_token = True) 
    tokenizer.fit_on_texts(corpus)
    
    return tokenizer 

## Encode the text into the sequence 

def encode_text(tokenizer, corpus, max_len):
    encoded = tokenizer.texts_to_sequences(corpus) # this will encode the text into the sequence    
    
    padded = sequence.pad_sequences(encoded, maxlen=max_len, padding='post')  # we add 0 to the words 
    # the sequence to the same length 
    
    return padded

# %%
train['length'] = train['review_processed'].apply(len)
test['length'] = test['review_processed'].apply(len)

# %%
train.head(3)
# Out:
#                                               review sentiment  word_counts  \
# 0  If you are looking for a movie that doesn't ta...  positive          271
# 1  THE BEAVER TRILOGY is, without a doubt, one of...  positive          217
# 2  If Andrei Tarkovsky had been a hack, he would ...  negative          118
#
#                                     review_processed  sentiment_encoded  \
# 0  look movie doesnt take seriously haggard must ...                  1
# 1  beaver trilogy without doubt one brilliant fil...                  1
# 2  andrei tarkovsky hack would direct mother son ...                  0
#
#    length
# 0     782
# 1     735
# 2     426

# %%
max_len = train['length'].max()

# %%
tokenizer = create_tokenizer(corpus=train['review_processed'].tolist(),
                             max_len=max_len)

# %%
seq = train['review_processed'].iloc[0].split()
print(seq)
# Out:
# ['look', 'movie', 'doesnt', 'take', 'seriously', 'haggard', 'must', 'say', 'write', 'anything', 'see', 'cky', 'camp', 'kill', 'video', 'movie', 'likely', 'wont', 'funny', 'advice', 'watch', 'clip', 'video', 'bam', 'friend', 'make', 'haggard', 'take', 'seriously', 'never', 'purpose', 'throughout', 'movie', 'random', 'moment', 'nothing', 'plot', 'may', 'get', 'annoy', 'nothing', 'control', 'even', 'plot', 'stay', 'focus', 'story', 'ryan', 'dunns', 'character', 'unfold', 'quite', 'nicely', 'plot', 'told', 'base', 'true', 'story', 'partof', 'ryan', 'dunns', 'exgirlfriend', 'brandon', 'dicamillo', 'far', 'best', 'character', 'movie', 'lot', 'talent', 'know', 'make', 'people', 'laugh', 'stole', 'movie', 'ask', 'overall', 'love', 'movie', 'simplicity', 'straight', 'weirdness', 'bam', 'movie', 'people', 'go', 'normal', 'haggard', 'fill', 'hilarious', 'quote', 'friend', 'constantly', 'use', 'since', 'first', 'time', 'saw', 'ive', 'see', 'movie', 'time', 'still', 'find', 'new', 'thing', 'every', 'time', 'soundtrack', 'good', 'everything', 'gnar', 'kill', 'new', 'order', 'techno', 'dont', 'go', 'movie', 'high', 'expectation', 'let', 'unfold', 'judge']

# %% [markdown]
# And now we encoded: I take the tokenizer that I train. They are the indices of the words

# %%
seq_encoded = tokenizer.texts_to_sequences([seq])
print(seq_encoded)
# Out:
# [[24, 3, 70, 32, 494, 7401, 129, 26, 91, 152, 8, 10370, 917, 106, 283, 3, 1081, 379, 79, 1645, 14, 1809, 283, 4414, 117, 6, 7401, 32, 494, 50, 925, 370, 3, 1263, 161, 80, 45, 110, 9, 475, 80, 758, 17, 45, 462, 533, 18, 1543, 22346, 13, 3117, 100, 1528, 45, 456, 317, 204, 18, 57216, 1543, 22346, 7839, 7402, 23857, 147, 54, 13, 3, 62, 414, 35, 6, 27, 144, 2989, 3, 422, 339, 37, 3, 3983, 653, 8194, 4414, 3, 27, 15, 1057, 7401, 590, 495, 1650, 117, 1116, 71, 149, 33, 11, 125, 111, 8, 3, 11, 58, 59, 87, 40, 86, 11, 599, 12, 184, 42722, 106, 87, 434, 8978, 34, 15, 3, 193, 1094, 153, 3117, 1307]]

# %%
tokenizer.texts_to_sequences([['book']])
# Out:
# [[159]]

# %%
X_train = encode_text(tokenizer,
                      corpus = train['review_processed'].tolist(),
                      max_len = max_len)

# %%
X_test = encode_text(tokenizer,
                      corpus = test['review_processed'].tolist(),
                      max_len = max_len)

# %%
X_train
# Out:
# array([[1188,   20,   35, ...,    0,    0,    0],
#        [ 591,   56,   39, ...,    0,    0,    0],
#        [7622, 1684, 1693, ...,    0,    0,    0],
#        ...,
#        [4989,  867,   85, ...,    0,    0,    0],
#        [9409,   75,  120, ...,    0,    0,    0],
#        [ 110, 1338,  617, ...,    0,    0,    0]], dtype=int32)

# %% [markdown]
# The ceros is because we are using padding

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('look', 14373),
#              ('movie', 74074),
#              ('doesnt', 6663),
#              ('take', 12859),
#              ('seriously', 1479),
#              ('haggard', 52),
#              ('must', 4635),
#              ('say', 14184),
#              ('write', 5631),
#              ('anything', 4229),
#              ('see', 30557),
#              ('cky', 31),
#              ('camp', 779),
#              ('kill', 5202),
#              ('video', 2552),
#              ('likely', 649),
#              ('wont', 1948),
#              ('funny', 6254),
#              ('advice', 393),
#              ('watch', 20400),
#              ('clip', 350),
#              ('bam', 111),
#              ('friend', 4790),
#              ('make', 32876),
#              ('never', 9618),
#              ('purpose', 772),
#              ('throughout', 1971),
#              ('random', 541),
#              ('moment', 3959),
#              ('nothing', 6201),
#              ('plot', 9842),
#              ('may', 5015),
#              ('get', 25992),
#              ('annoy', 1506),
#              ('control', 968),
#              ('even', 18819),
#              ('stay', 1552),
#              ('focus', 1361),
#              ('story', 18191),
#              ('ryan', 431),
#              ('dunns', 8),
#              ('character', 20662),
#              ('unfold', 177),
#              ('quite', 5401),
#              ('nicely', 437),
#              ('told', 1567),
#              ('base', 2314),
#              ('true', 3267),
#              ('partof', 1),
#              ('exgirlfriend', 48),
#              ('brandon', 52),
#              ('dicamillo', 7),
#              ('far', 4320),
#              ('best', 9146),
#              ('lot', 7245),
#              ('talent', 1760),
#              ('know', 12604),
#              ('people', 13679),
#              ('laugh', 4348),
#              ('stole', 186),
#              ('ask', 1735),
#              ('overall', 2159),
#              ('love', 12487),
#              ('simplicity', 128),
#              ('straight', 1126),
#              ('weirdness', 45),
#              ('go', 20066),
#              ('normal', 666),
#              ('fill', 1244),
#              ('hilarious', 1478),
#              ('quote', 392),
#              ('constantly', 627),
#              ('use', 6628),
#              ('since', 4282),
#              ('first', 12801),
#              ('time', 22093),
#              ('saw', 4711),
#              ('ive', 5003),
#              ('still', 8179),
#              ('find', 8108),
#              ('new', 5944),
#              ('thing', 12006),
#              ('every', 5967),
#              ('soundtrack', 1231),
#              ('good', 21442),
#              ('everything', 3538),
#              ('gnar', 2),
#              ('order', 1681),
#              ('techno', 39),
#              ('dont', 12646),
#              ('high', 3455),
#              ('expectation', 642),
#              ('let', 4207),
#              ('judge', 524),
#              ('beaver', 47),
#              ('trilogy', 284),
#              ('without', 4766),
#              ('doubt', 1284),
#              ('one', 39996),
#              ('brilliant', 1707),
#              ('film', 68851),
#              ('ever', 8713),
#              ('lucky', 358),
#              ('enough', 5066),
#              ('catch', 885),
#              ('along', 2746),
#              ('qa', 28),
#              ('session', 128),
#              ('director', 6961),
#              ('trent', 28),
#              ('harris', 316),
#              ('ny', 106),
#              ('festival', 619),
#              ('year', 9207),
#              ('back', 7016),
#              ('bought', 696),
#              ('copy', 1154),
#              ('website', 163),
#              ('believe', 4570),
#              ('sincerely', 97),
#              ('recommend', 3294),
#              ('search', 801),
#              ('name', 4072),
#              ('web', 193),
#              ('buying', 273),
#              ('site', 382),
#              ('he', 4270),
#              ('incredibly', 931),
#              ('nice', 2830),
#              ('guy', 6680),
#              ('boot', 239),
#              ('confuse', 1168),
#              ('cameraman', 99),
#              ('fictional', 223),
#              ('section', 363),
#              ('trentbr', 1),
#              ('br', 86438),
#              ('admit', 1001),
#              ('could', 11414),
#              ('probably', 4190),
#              ('sean', 375),
#              ('penn', 172),
#              ('version', 3333),
#              ('like', 32373),
#              ('tryout', 15),
#              ('crispin', 54),
#              ('glover', 135),
#              ('orkly', 3),
#              ('kid', 4512),
#              ('interest', 5998),
#              ('curiosity', 185),
#              ('item', 185),
#              ('youre', 2875),
#              ('fan', 4862),
#              ('pretty', 5425),
#              ('though', 6306),
#              ('making', 28),
#              ('big', 6101),
#              ('star', 5843),
#              ('gritty', 278),
#              ('bw', 86),
#              ('videobr', 34),
#              ('also', 13378),
#              ('glovers', 19),
#              ('role', 6002),
#              ('would', 17997),
#              ('update', 178),
#              ('documentary', 1580),
#              ('original', 4712),
#              ('groovin', 4),
#              ('gary', 408),
#              ('youll', 1992),
#              ('nervous', 136),
#              ('laughter', 330),
#              ('head', 2853),
#              ('andrei', 27),
#              ('tarkovsky', 32),
#              ('hack', 209),
#              ('direct', 3010),
#              ('mother', 2374),
#              ('son', 2037),
#              ('instead', 3174),
#              ('mirror', 345),
#              ('single', 1293),
#              ('pretentious', 344),
#              ('anywhere', 438),
#              ('world', 5470),
#              ('convince', 568),
#              ('care', 2694),
#              ('guess', 2341),
#              ('im', 6973),
#              ('sure', 3870),
#              ('arent', 1290),
#              ('actor', 9650),
#              ('play', 8897),
#              ('least', 4536),
#              ('nature', 977),
#              ('seem', 10586),
#              ('ridiculously', 172),
#              ('touch', 1781),
#              ('change', 2932),
#              ('wherever', 68),
#              ('necessary', 447),
#              ('macintosh', 10),
#              ('computer', 693),
#              ('sokurov', 9),
#              ('come', 12196),
#              ('technique', 439),
#              ('hackneyed', 108),
#              ('distort', 71),
#              ('aspect', 1229),
#              ('ration', 20),
#              ('born', 530),
#              ('yesterday', 176),
#              ('buy', 1211),
#              ('garbage', 676),
#              ('tarzan', 270),
#              ('jane', 656),
#              ('living', 1536),
#              ('happily', 196),
#              ('jungle', 334),
#              ('men', 2687),
#              ('ivory', 39),
#              ('civilization', 133),
#              ('refuse', 470),
#              ('leave', 2296),
#              ('fall', 3131),
#              ('determine', 306),
#              ('backeven', 2),
#              ('mean', 3498),
#              ('tarzanbr', 2),
#              ('raritya', 1),
#              ('sequel', 1488),
#              ('thats', 5464),
#              ('well', 22504),
#              ('ape', 214),
#              ('man', 8256),
#              ('dreadful', 346),
#              ('special', 3171),
#              ('effect', 4275),
#              ('sort', 2481),
#              ('drag', 776),
#              ('much', 14224),
#              ('adult', 1169),
#              ('ton', 262),
#              ('blatant', 149),
#              ('racism', 260),
#              ('black', 3082),
#              ('shot', 4307),
#              ('death', 3070),
#              ('point', 5744),
#              ('blankand', 1),
#              ('really', 17361),
#              ('there', 4654),
#              ('plenty', 900),
#              ('blood', 1627),
#              ('gore', 1450),
#              ('violence', 1488),
#              ('uncut', 94),
#              ('print', 376),
#              ('lengthy', 107),
#              ('underwater', 113),
#              ('swim', 250),
#              ('totally', 2058),
#              ('nude', 245),
#              ('obvious', 1517),
#              ('sexual', 956),
#              ('content', 592),
#              ('wear', 988),
#              ('next', 2537),
#              ('imply', 159),
#              ('sleep', 752),
#              ('together', 3236),
#              ('sexwithout', 1),
#              ('married', 802),
#              ('wouldnt', 1573),
#              ('bother', 1074),
#              ('anyone', 3917),
#              ('today', 1916),
#              ('extremebr', 12),
#              ('aside', 703),
#              ('welldirected', 23),
#              ('fastmoving', 21),
#              ('full', 2509),
#              ('adventure', 905),
#              ('excitement', 292),
#              ('weissmuller', 24),
#              ('skimpy', 32),
#              ('lion', 253),
#              ('cloth', 51),
#              ('certainly', 2209),
#              ('treat', 1023),
#              ('eye', 2816),
#              ('janes', 54),
#              ('outfit', 232),
#              ('reveal', 864),
#              ('think', 13058),
#              ('maureen', 46),
#              ('osullivan', 22),
#              ('bad', 19377),
#              ('weismuller', 12),
#              ('perfect', 2349),
#              ('everybody', 600),
#              ('else', 2816),
#              ('okbr', 35),
#              ('easily', 1221),
#              ('weismullerohara', 1),
#              ('worth', 3472),
#              ('necessarily', 273),
#              ('socalled', 223),
#              ('classic', 2965),
#              ('standard', 1082),
#              ('main', 3456),
#              ('reason', 4193),
#              ('experience', 1965),
#              ('feel', 7014),
#              ('youve', 1103),
#              ('experienced', 324),
#              ('countercultural', 2),
#              ('idealism', 34),
#              ('matter', 2139),
#              ('however', 5117),
#              ('badbr', 206),
#              ('happen', 3523),
#              ('english', 1414),
#              ('literature', 125),
#              ('class', 1218),
#              ('suny', 3),
#              ('geneseo', 1),
#              ('appear', 2877),
#              ('meaningless', 165),
#              ('composition', 119),
#              ('icon', 158),
#              ('simply', 2938),
#              ('thrown', 613),
#              ('togetherbr', 104),
#              ('unsatisfied', 36),
#              ('do', 4425),
#              ('job', 3442),
#              ('conveyed', 81),
#              ('desolate', 54),
#              ('view', 3007),
#              ('future', 1192),
#              ('leaf', 1041),
#              ('unsure', 79),
#              ('angry', 509),
#              ('perhaps', 2375),
#              ('sought', 74),
#              ('explore', 428),
#              ('youth', 400),
#              ('exemplifiedbr', 1),
#              ('zabriskie', 25),
#              ('tell', 4538),
#              ('onesided', 38),
#              ('predictable', 1234),
#              ('conveys', 88),
#              ('clichéd', 292),
#              ('rebellious', 85),
#              ('desire', 657),
#              ('existence', 356),
#              ('mark', 1065),
#              ('daria', 25),
#              ('share', 817),
#              ('antiestablishment', 18),
#              ('student', 1110),
#              ('inauthentic', 6),
#              ('govt', 10),
#              ('rebel', 233),
#              ('mediocre', 504),
#              ('thriller', 1309),
#              ('abuse', 438),
#              ('wife', 2992),
#              ('lam', 56),
#              ('link', 315),
#              ('circumstantially', 1),
#              ('husband', 1495),
#              ('sister', 1498),
#              ('prove', 817),
#              ('alive', 716),
#              ('follow', 3144),
#              ('lead', 4412),
#              ('across', 1500),
#              ('state', 1483),
#              ('peril', 65),
#              ('increase', 196),
#              ('stop', 2135),
#              ('chase', 1212),
#              ('traditional', 336),
#              ('goodcop', 1),
#              ('badcop', 1),
#              ('pair', 532),
#              ('partner', 477),
#              ('innocence', 223),
#              ('interested', 963),
#              ('closing', 253),
#              ('case', 2397),
#              ('home', 2708),
#              ('often', 2308),
#              ('able', 1909),
#              ('corner', 264),
#              ('suspect', 712),
#              ('capture', 1286),
#              ('player', 796),
#              ('meet', 1964),
#              ('remote', 244),
#              ('town', 1841),
#              ('desert', 547),
#              ('truth', 1057),
#              ('begin', 4595),
#              ('deadly', 291),
#              ('consequence', 276),
#              ('somebr', 11),
#              ('wow', 526),
#              ('act', 12593),
#              ('tranquilize', 1),
#              ('cop', 1424),
#              ('couldnt', 2299),
#              ('police', 1575),
#              ('station', 586),
#              ('happens', 1614),
#              ('twice', 522),
#              ('everyone', 3129),
#              ('onedimensional', 145),
#              ('avoid', 1322),
#              ('costsbr', 23),
#              ('john', 3023),
#              ('carpenter', 284),
#              ('hand', 2594),
#              ('horror', 5332),
#              ('personal', 942),
#              ('favorite', 2023),
#              ('great', 14895),
#              ('hard', 3579),
#              ('put', 4580),
#              ('finger', 343),
#              ('work', 9819),
#              ('rare', 601),
#              ('occasion', 241),
#              ('place', 4380),
#              ('superior', 464),
#              ('alien', 1028),
#              ('create', 2086),
#              ('type', 1941),
#              ('moody', 135),
#              ('atmospheric', 197),
#              ('hell', 1686),
#              ('fact', 5408),
#              ('wonderful', 2381),
#              ('btw', 98),
#              ('paranoia', 113),
#              ('unmatched', 20),
#              ('truly', 2632),
#              ('worship', 86),
#              ('buff', 264),
#              ('taste', 782),
#              ('cheap', 1323),
#              ('lousy', 343),
#              ('dvd', 3692),
#              ('alpha', 38),
#              ('day', 5395),
#              ('silly', 1336),
#              ('science', 762),
#              ('fiction', 649),
#              ('sexed', 9),
#              ('replete', 28),
#              ('unscientific', 4),
#              ('scantily', 41),
#              ('clad', 70),
#              ('girl', 5621),
#              ('melodrama', 286),
#              ('enjoyable', 1178),
#              ('appreciate', 1016),
#              ('kind', 4337),
#              ('stuff', 1709),
#              ('suspend', 159),
#              ('disbelief', 226),
#              ('actually', 6349),
#              ('creeped', 27),
#              ('psychotic', 156),
#              ('beating', 191),
#              ('closet', 155),
#              ('toward', 368),
#              ('end', 13358),
#              ('body', 1689),
#              ('whats', 1284),
#              ('another', 6413),
#              ('word', 2652),
#              ('mindfing', 1),
#              ('mogul', 25),
#              ('vhs', 427),
#              ('old', 7003),
#              ('distributor', 81),
#              ('whose', 1407),
#              ('catalog', 27),
#              ('wish', 1910),
#              ('hadbr', 32),
#              ('poor', 2762),
#              ('retitled', 20),
#              ('attic', 56),
#              ('admonition', 4),
#              ('repeat', 637),
#              ('villa', 55),
#              ('ground', 637),
#              ('idea', 3799),
#              ('hour', 3007),
#              ('earlier', 885),
#              ('learn', 1720),
#              ('therebr', 214),
#              ('start', 6081),
#              ('turin', 1),
#              ('italy', 239),
#              ('two', 9733),
#              ('fight', 2896),
#              ('woman', 6367),
#              ('regret', 354),
#              ('pull', 1413),
#              ('knife', 249),
#              ('stab', 166),
#              ('flees', 40),
#              ('shes', 2059),
#              ('left', 3036),
#              ('chair', 263),
#              ('move', 3462),
#              ('garden', 175),
#              ('earthbr', 32),
#              ('present', 1839),
#              ('thirty', 240),
#              ('later', 3101),
#              ('séance', 16),
#              ('suddenly', 748),
#              ('child', 3665),
#              ('prologue', 68),
#              ('inherit', 85),
#              ('house', 2982),
#              ('daughter', 1829),
#              ('played', 3798),
#              ('actress', 2187),
#              ('reoccur', 2),
#              ('haunt', 705),
#              ('warning', 45),
#              ('forfeit', 8),
#              ('die', 2326),
#              ('lawyer', 294),
#              ('try', 9324),
#              ('investigate', 280),
#              ('little', 9273),
#              ('family', 4590),
#              ('curse', 396),
#              ('unfortunately', 1965),
#              ('boring', 2571),
#              ('moviebr', 1273),
#              ('amuse', 868),
#              ('smallprint', 1),
#              ('disclaimer', 39),
#              ('box', 959),
#              ('read', 2944),
#              ('scene', 15515),
#              ('depict', 518),
#              ('packaging', 39),
#              ('artist', 652),
#              ('impression', 650),
#              ('represent', 494),
#              ('actual', 1126),
#              ('cover', 1358),
#              ('illustration', 38),
#              ('less', 2629),
#              ('accurately', 109),
#              ('aforementioned', 182),
#              ('underground', 279),
#              ('although', 3719),
#              ('different', 3423),
#              ('sometimes', 1707),
#              ('art', 2057),
#              ('recall', 441),
#              ('reviewer', 734),
#              ('predictor', 2),
#              ('scale', 319),
#              ('photo', 223),
#              ('receive', 624),
#              ('blockbuster', 326),
#              ('attraction', 225),
#              ('forward', 925),
#              ('release', 2768),
#              ('date', 1211),
#              ('sound', 3432),
#              ('reasonable', 184),
#              ('cast', 6355),
#              ('alone', 1405),
#              ('guaranteed', 101),
#              ('sidesplitter', 2),
#              ('whoa', 28),
#              ('apart', 872),
#              ('wall', 625),
#              ('bet', 379),
#              ('event', 1748),
#              ('borebr', 5),
#              ('become', 3694),
#              ('comedy', 5099),
#              ('afraid', 446),
#              ('help', 3896),
#              ('fine', 2212),
#              ('reputation', 286),
#              ('cleese', 23),
#              ('rowan', 38),
#              ('atkinson', 28),
#              ('way', 12271),
#              ('absolutely', 2249),
#              ('adore', 145),
#              ('lady', 1444),
#              ('columnist', 22),
#              ('barbara', 327),
#              ('stanwyck', 195),
#              ('major', 1434),
#              ('homemaking', 3),
#              ('magazine', 227),
#              ('delivers', 534),
#              ('welcome', 347),
#              ('article', 90),
#              ('month', 615),
#              ('include', 2939),
#              ('detail', 1121),
#              ('awesome', 669),
#              ('life', 10817),
#              ('beautiful', 3077),
#              ('connecticut', 47),
#              ('trouble', 882),
#              ('owner', 490),
#              ('monthly', 11),
#              ('publication', 28),
#              ('demand', 455),
#              ('ww', 110),
#              ('hero', 1879),
#              ('guest', 392),
#              ('christmas', 746),
#              ('holiday', 260),
#              ('worried', 163),
#              ('small', 2460),
#              ('york', 1036),
#              ('apartment', 500),
#              ('isnt', 4720),
#              ('baby', 1005),
#              ('cant', 5572),
#              ('cook', 199),
#              ('hilarity', 101),
#              ('romance', 1059),
#              ('ensues', 106),
#              ('believable', 1020),
#              ('effort', 1499),
#              ('save', 2545),
#              ('face', 3123),
#              ('keep', 3748),
#              ('fire', 1210),
#              ('sydney', 84),
#              ('greenstreet', 36),
#              ('delightful', 360),
#              ('highly', 1686),
#              ('lover', 917),
#              ('cooking', 88),
#              ('show', 16169),
#              ('want', 9788),
#              ('hair', 763),
#              ('questionwho', 1),
#              ('slap', 268),
#              ('plain', 847),
#              ('meal', 104),
#              ('minute', 5393),
#              ('need', 4927),
#              ('already', 1961),
#              ('bag', 265),
#              ('prechopped', 1),
#              ('except', 1618),
#              ('chop', 171),
#              ('green', 580),
#              ('almost', 4620),
#              ('tv', 4181),
#              ('chef', 65),
#              ('prep', 18),
#              ('sandra', 179),
#              ('lee', 984),
#              ('oh', 2051),
#              ('yepthey', 1),
#              ('toobr', 195),
#              ('comment', 2292),
#              ('hat', 853),
#              ('evoo', 2),
#              ('add', 2688),
#              ('delish', 2),
#              ('list', 981),
#              ('stupid', 2539),
#              ('tag', 180),
#              ('obviousa', 2),
#              ('loud', 542),
#              ('gregarious', 1),
#              ('audience', 3790),
#              ('lame', 1044),
#              ('mug', 84),
#              ('many', 9961),
#              ('camera', 2566),
#              ('u', 5778),
#              ('aint', 285),
#              ('cutest', 20),
#              ('something', 7464),
#              ('brazil', 194),
#              ('tupinambas', 2),
#              ('indian', 820),
#              ('french', 1225),
#              ('enemy', 493),
#              ('tupiniquins', 2),
#              ('portuguese', 65),
#              ('frenchman', 48),
#              ('arduíno', 1),
#              ('colassanti', 1),
#              ('tupinambás', 1),
#              ('spite', 272),
#              ('trial', 311),
#              ('becomes', 1951),
#              ('slave', 187),
#              ('maritally', 1),
#              ('seboipepe', 1),
#              ('ana', 29),
#              ('maria', 184),
#              ('magalhães', 3),
#              ('us', 805),
#              ('powder', 34),
#              ('cannon', 133),
#              ('behind', 1775),
#              ('defeat', 268),
#              ('battle', 1146),
#              ('celebrate', 164),
#              ('victory', 112),
#              ('decide', 1842),
#              ('eat', 864),
#              ('como', 8),
#              ('era', 805),
#              ('gostoso', 2),
#              ('meu', 4),
#              ('francês', 2),
#              ('low', 2369),
#              ('budget', 2408),
#              ('brazilian', 70),
#              ('nélson', 1),
#              ('pereira', 11),
#              ('santos', 10),
#              ('screenplay', 982),
#              ('spoken', 213),
#              ('tupi', 2),
#              ('natural', 646),
#              ('light', 2055),
#              ('realistic', 1074),
#              ('perform', 742),
#              ('naked', 654),
#              ('magnificent', 401),
#              ('give', 12933),
#              ('stun', 708),
#              ('performance', 6613),
#              ('produce', 1311),
#              ('musician', 241),
#              ('zé', 1),
#              ('rodrix', 1),
#              ('exploitation', 304),
#              ('country', 1601),
#              ('european', 441),
#              ('trading', 29),
#              ('exchange', 220),
#              ('comb', 70),
#              ('resource', 127),
#              ('award', 899),
#              ('national', 420),
#              ('cinema', 2159),
#              ('brasília', 2),
#              ('de', 996),
#              ('brazília', 1),
#              ('brasileiro', 1),
#              ('nelson', 184),
#              ('dialog', 1446),
#              ('humberto', 1),
#              ('mauro', 1),
#              ('cenograph', 1),
#              ('régis', 1),
#              ('monteiro', 1),
#              ('critic', 759),
#              ('association', 78),
#              ('são', 4),
#              ('paulo', 15),
#              ('associação', 1),
#              ('paulista', 1),
#              ('críticos', 1),
#              ('arte', 2),
#              ('revelation', 262),
#              ('prize', 160),
#              ('vote', 566),
#              ('eightbr', 24),
#              ('title', 2543),
#              ('tasty', 46),
#              ('faithful', 245),
#              ('adaptation', 756),
#              ('masuji', 2),
#              ('ibuses', 1),
#              ('novel', 1605),
#              ('rain', 297),
#              ('book', 4066),
#              ('thoughtprovoking', 132),
#              ('revolves', 221),
#              ('around', 5210),
#              ('couple', 2870),
#              ('attempt', 2854),
#              ('niece', 108),
#              ('successfully', 214),
#              ('suitor', 44),
#              ('rumor', 92),
#              ('suffers', 303),
#              ('radiation', 56),
#              ('sickness', 60),
#              ('walk', 1944),
#              ('hiroshima', 29),
#              ('bombing', 79),
#              ('tragic', 506),
#              ('horrify', 232),
#              ('episode', 3523),
#              ('trap', 549),
#              ('cartoon', 1096),
#              ('war', 3519),
#              ('al', 436),
#              ('bizarreashell', 1),
#              ('super', 492),
#              ('cereal', 15),
#              ('darn', 127),
#              ('agree', 1007),
#              ('cartmankyle', 2),
#              ('cartman', 28),
#              ('superstitious', 16),
#              ('kyle', 121),
#              ('steal', 1201),
#              ('goldwhich', 1),
#              ('course', 3663),
#              ('fake', 815),
#              ('within', 1210),
#              ('inch', 93),
#              ('wake', 340),
#              ('crazy', 948),
#              ('conversation', 457),
#              ('completely', 2872),
#              ('crap', 1421),
#              ('treasure', 320),
#              ('ok', 1512),
#              ('mystery', 1171),
#              ('theater', 1503),
#              ('figure', 1620),
#              ('joe', 855),
#              ('stuck', 514),
#              ('crummy', 49),
#              ('brother', 2190),
#              ('nephew', 106),
#              ('oscar', 1162),
#              ('win', 1296),
#              ('right', 4904),
#              ('soultaker', 17),
#              ('technically', 265),
#              ('call', 4099),
#              ('meant', 842),
#              ('extremely', 1579),
#              ('cheesy', 925),
#              ('didnt', 6563),
#              ('sense', 3334),
#              ('mention', 2243),
#              ('ability', 828),
#              ('mstk', 228),
#              ('simple', 1510),
#              ('ill', 1683),
#              ('explain', 1205),
#              ('momentbr', 34),
#              ('natalie', 117),
#              ('zach', 33),
#              ('broke', 207),
#              ('upper', 163),
#              ('middle', 1207),
#              ('gonna', 349),
#              ('zachs', 2),
#              ('car', 2153),
#              ('accident', 490),
#              ('angel', 521),
#              ('deathsoultaker', 1),
#              ('quota', 11),
#              ('soultaking', 1),
#              ('relationship', 1921),
#              ('race', 754),
#              ('five', 1171),
#              ('million', 745),
#              ('clock', 106),
#              ('soul', 804),
#              ('livesbr', 58),
#              ('zeppelin', 22),
#              ('wrong', 2617),
#              ('sang', 85),
#              ('stairway', 35),
#              ('heaven', 451),
#              ('wonder', 2427),
#              ('sabbith', 1),
#              ('lol', 122),
#              ('basically', 1356),
#              ('hole', 802),
#              ('yet', 3953),
#              ('somehow', 1101),
#              ('press', 264),
#              ('button', 244),
#              ('open', 1558),
#              ('door', 786),
#              ('strange', 1329),
#              ('bit', 4885),
#              ('distract', 294),
#              ('rush', 498),
#              ('underappreciated', 45),
#              ('sheenestovez', 1),
#              ('brotherbr', 19),
#              ('cancel', 204),
#              ('rerun', 144),
#              ('enjoy', 4694),
#              ('third', 980),
#              ('season', 1289),
#              ('fourth', 245),
#              ('fifth', 126),
#              ('irate', 12),
#              ('problem', 3320),
#              ('irrelevant', 126),
#              ('scenario', 327),
#              ('history', 1859),
#              ('jr', 436),
#              ('parent', 1316),
#              ('second', 3173),
#              ('someone', 3469),
#              ('ex', 183),
#              ('katie', 47),
#              ('franklin', 76),
#              ('idiotic', 218),
#              ('tedious', 317),
#              ('vex', 5),
#              ('beat', 696),
#              ('stupidity', 260),
#              ('unconscious', 62),
#              ('zealous', 11),
#              ('dork', 31),
#              ('clarie', 1),
#              ('claimed', 130),
#              ('boyfriend', 646),
#              ('pushover', 9),
#              ('last', 4514),
#              ('noah', 86),
#              ('graycabey', 1),
#              ('scary', 1280),
#              ('terrible', 2424),
#              ('combination', 335),
#              ('urkle', 1),
#              ('tj', 9),
#              ('henderson', 35),
#              ('jumped', 117),
#              ('shark', 236),
#              ('realism', 395),
#              ('sign', 674),
#              ('force', 2197),
#              ('eveytime', 2),
#              ('bfbefore', 1),
#              ('frank', 654),
#              ('entertain', 2644),
#              ('rarely', 486),
#              ('indie', 278),
#              ('cross', 614),
#              ('eyed', 53),
#              ('gem', 646),
#              ('writer', 2068),
#              ('tackle', 148),
#              ('challenge', 452),
#              ('evil', 1992),
#              ('roommate', 142),
#              ('script', 4721),
#              ('plight', 133),
#              ('struggle', 991),
#              ('mix', 656),
#              ('commit', 586),
#              ('ernie', 51),
#              ('despite', 1968),
#              ('tiny', 339),
#              ('adam', 521),
#              ('jones', 601),
#              ('manages', 863),
#              ('serious', 1498),
#              ('mess', 1054),
#              ('wait', 1977),
#              ('chris', 604),
#              ('farley', 80),
#              ('david', 1555),
#              ('spade', 118),
#              ('cynical', 225),
#              ('sarcastic', 90),
#              ('yin', 11),
#              ('farleys', 7),
#              ('huey', 7),
#              ('yang', 18),
#              ('achieves', 79),
#              ('stroke', 126),
#              ('comic', 1363),
#              ...])

# %%
vocab_size = len(tokenizer.word_index) + 1 + 1 # we add 1 for the padding and 1 for the out of vocabulary token

# %%
X_train.shape
# Out:
# (12500, 8307)

# %%
X_test.shape
# Out:
# (12500, 8307)

# %%
'''
def CNN(max_length, vocab_size):
    kernel = 'normal'
    embedding_size = 100 # the size of the vector space in which words will be embedded
    drop_out_value = 0.2 # the fraction of the units to drop for the linear transformation of the inputs
    kernel_size = 6 # the length of the 1D convolution window
    
    model = Sequential(name = 'sequential')
    
    model.add (Embedding(input_dim = vocab_size, 
                         output_dim = embedding_size, 
                         input_length = max_length,
                         name = 'embedding'))
    
    model.add(Conv1D(filters = 64, kernel_size = kernel_size, activation = 'relu', name = 'conv_1'))
    model.add(Dropout(drop_out_value, name = 'dropout_1'))
    model.add(MaxPooling1D(pool_size = 2))
    
    model.add(Conv1D(filters = 256, kernel_size = kernel_size, activation = 'relu', name = 'conv_2'))
    model.add(Dropout(drop_out_value, name = 'dropout_2'))
    model.add(MaxPooling1D(pool_size = 2))
    
    model.add(Flatten())
    
    model.add(Dense(1, activation = 'sigmoid', kernel_initializer = kernel, name = 'dense_2'))
    #sigmoid because is used for a binary classification
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    
    return model
'''

# %%
# Define a function to create a Convolutional Neural Network (CNN) for text classification.
# - `max_length`: The length of the input sequences (padded/truncated).
# - `vocab_size`: The size of the vocabulary, including padding and OOV tokens.
def CNN(max_length, vocab_size):
    # Initialize kernel type, embedding size, dropout value, and kernel size.
    kernel = 'normal'               # Kernel initializer for dense layers.
    embedding_size = 100            # Dimension of the word embedding vectors.
    drop_out_value = 0.5            # Dropout rate to reduce overfitting.
    kernel_size = 6                 # Size of the kernel for the convolutional layers.

    # Create a sequential model.
    model = Sequential(name='sequential')

    # Add an embedding layer:
    # - `input_dim=vocab_size`: Vocabulary size for the embedding layer.
    # - `output_dim=embedding_size`: Size of each word embedding vector.
    # - `input_length=max_length`: Length of each input sequence (padded/truncated).
    model.add(Embedding(input_dim=vocab_size,
                        output_dim=embedding_size,
                        input_length=max_length,
                        name='embedding'
                        )
    )

    # Add the first 1D convolutional layer:
    # - `filters=64`: Number of output filters (feature maps).
    # - `kernel_size=kernel_size`: Size of the convolutional window.
    # - `activation='relu'`: Activation function to apply non-linearity.
    model.add(Conv1D(filters=64, kernel_size=kernel_size, activation='relu', name='conv_1'))

    # Add the first dropout layer:
    # - `rate=drop_out_value`: Randomly set 50% of input units to 0 during training.
    model.add(Dropout(drop_out_value, name='dropout_1'))

    # Add the first max-pooling layer:
    # - `pool_size=2`: Reduces the dimensionality of the feature maps by taking the maximum value in each pool.
    model.add(MaxPooling1D(pool_size=2))

    # Add the second 1D convolutional layer:
    # - `filters=256`: Number of output filters.
    # - `kernel_size=kernel_size`: Size of the convolutional window.
    # - `activation='relu'`: Activation function.
    model.add(Conv1D(filters=256, kernel_size=kernel_size, activation='relu', name='conv_2'))

    # Add the second dropout layer.
    model.add(Dropout(drop_out_value, name='dropout_2'))

    # Add the second max-pooling layer.
    model.add(MaxPooling1D(pool_size=2))

    # Flatten the output:
    # - Converts the multi-dimensional feature maps into a single vector for the dense layer.
    model.add(Flatten())

    # Add the final output layer:
    # - `units=1`: Single output for binary classification (positive/negative sentiment).
    # - `activation='sigmoid'`: Sigmoid activation to produce probabilities between 0 and 1.
    # - `kernel_initializer=kernel`: Initializer for weights.
    model.add(Dense(1, activation='sigmoid', kernel_initializer=kernel, name='dense_2'))
    
    #sigmoid because is used for a binary classification
    # multiclass classification would use softmax
    # regression would use linear activation

    # Compile the model:
    # - `loss='binary_crossentropy'`: Loss function for binary classification.
    # - `optimizer='adam'`: Adaptive learning rate optimization algorithm.
    # - `metrics=['accuracy']`: Track accuracy during training and evaluation.
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Return the compiled model.
    return model

# %% [markdown]
# Define the target Variables:

# %%
y_train = train['sentiment_encoded'].values
y_test = test['sentiment_encoded'].values

# %%
cnn_model = CNN(max_len, vocab_size)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', 
                               patience = 3,
                               mode = 'max',
                               restore_best_weights = True) # we want to maximize the validation accuracy when we stop earlier

# %%
tf.keras.backend.clear_session()

# %%
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("Sample in X_train:", X_train[0])
# Out:
# X_train shape: (12500, 8307)
# y_train shape: (37500,)
# Sample in X_train: [1188.   20.   35. ...    0.    0.    0.]

# %%
cnn_history = cnn_model.fit(X_train, y_train,
                            epochs = 8,
                            batch_size = 64,
                            validation_split = 0.5,
                            callbacks = [early_stopping])
# Out:
# Epoch 1/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.5009 - loss: 0.9747 - val_accuracy: 0.4891 - val_loss: 0.6942
# Epoch 2/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.5981 - loss: 0.6749 - val_accuracy: 0.4986 - val_loss: 0.6961
# Epoch 3/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.7535 - loss: 0.5480 - val_accuracy: 0.5059 - val_loss: 0.7365
# Epoch 4/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9654 - loss: 0.1403 - val_accuracy: 0.4974 - val_loss: 0.8691
# Epoch 5/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.9947 - loss: 0.0282 - val_accuracy: 0.5030 - val_loss: 0.9883
# Epoch 6/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9988 - loss: 0.0104 - val_accuracy: 0.4930 - val_loss: 1.0947
# Epoch 7/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.9989 - loss: 0.0058 - val_accuracy: 0.5016 - val_loss: 1.1156
# Epoch 8/8
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 369s 4s/step - accuracy: 0.9984 - loss: 0.0075 - val_accuracy: 0.4995 - val_loss: 1.1265
